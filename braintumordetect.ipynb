# %%
import zipfile

# %%
zip=zipfile.ZipFile('/content/brain.yolov11.zip')

# %%
zip.extractall()

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolo11n.pt')

# %%
model.train(data='/content/data.yaml',epochs=100,patience=20)
# Out:
# Ultralytics 8.4.112 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.save('btumour.pt')

# %%
mymodel=YOLO('btumour.pt')

# %%
pred=mymodel.predict('/content/test/images/1002_jpg.rf.46AuqSjle77MKfF7wtNN.jpg')
# Out:
# image 1/1 /content/test/images/1002_jpg.rf.46AuqSjle77MKfF7wtNN.jpg: 640x640 1 Astrocytoma, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
pred2=mymodel.predict('/content/test/images/1036_jpg.rf.7pcvAcnN4aJCHZVStNiq.jpg')
# Out:
# image 1/1 /content/test/images/1036_jpg.rf.7pcvAcnN4aJCHZVStNiq.jpg: 640x640 1 Astrocytoma, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred2[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
